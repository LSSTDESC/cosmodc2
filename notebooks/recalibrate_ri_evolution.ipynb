# %%
# %matplotlib inline
morange = u'#ff7f0e'
mblue = u'#1f77b4'
mgreen = u'#2ca02c'
mred = u'#d62728'
mpurple = u'#9467bd'
import h5py
# Out:
# /Users/aphearin/anaconda/lib/python2.7/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters

# %%
from cosmodc2.sdss_colors.sigmoid_r_minus_i import (
    default_ms_peak_ri, default_red_peak_ri, 
    red_sequence_peak_ri, main_sequence_peak_ri, 
    default_ms_peak_ri_zevol, default_red_peak_ri_zevol)

from cosmodc2.sdss_colors.alt_sigmoid_r_minus_i import (
    main_sequence_peak_ri as alt_main_sequence_peak_ri)

ngals = int(2e4)
redshift = np.linspace(0, 4, ngals)

ms_ri_mr25 = main_sequence_peak_ri(
        np.zeros(ngals) - 25, default_ms_peak_ri, redshift, default_ms_peak_ri_zevol)
ms_ri_mr23 = main_sequence_peak_ri(
        np.zeros(ngals) - 23, default_ms_peak_ri, redshift, default_ms_peak_ri_zevol)
ms_ri_mr21 = main_sequence_peak_ri(
        np.zeros(ngals) - 21, default_ms_peak_ri, redshift, default_ms_peak_ri_zevol)
ms_ri_mr19 = main_sequence_peak_ri(
        np.zeros(ngals) - 19, default_ms_peak_ri, redshift, default_ms_peak_ri_zevol)
ms_ri_mr17 = main_sequence_peak_ri(
        np.zeros(ngals) - 17, default_ms_peak_ri, redshift, default_ms_peak_ri_zevol)
ms_ri_mr12 = main_sequence_peak_ri(
        np.zeros(ngals) - 12, default_ms_peak_ri, redshift, default_ms_peak_ri_zevol)

rs_ri_mr25 = red_sequence_peak_ri(
        np.zeros(ngals) - 25, default_red_peak_ri, redshift, default_red_peak_ri_zevol)
rs_ri_mr23 = red_sequence_peak_ri(
        np.zeros(ngals) - 23, default_red_peak_ri, redshift, default_red_peak_ri_zevol)
rs_ri_mr21 = red_sequence_peak_ri(
        np.zeros(ngals) - 21, default_red_peak_ri, redshift, default_red_peak_ri_zevol)
rs_ri_mr19 = red_sequence_peak_ri(
        np.zeros(ngals) - 19, default_red_peak_ri, redshift, default_red_peak_ri_zevol)
rs_ri_mr17 = red_sequence_peak_ri(
        np.zeros(ngals) - 17, default_red_peak_ri, redshift, default_red_peak_ri_zevol)
rs_ri_mr12 = red_sequence_peak_ri(
        np.zeros(ngals) - 12, default_red_peak_ri, redshift, default_red_peak_ri_zevol)


alt_ms_ri_mr25 = alt_main_sequence_peak_ri(np.zeros(ngals) - 25, redshift)
alt_ms_ri_mr23 = alt_main_sequence_peak_ri(np.zeros(ngals) - 23, redshift)
alt_ms_ri_mr21 = alt_main_sequence_peak_ri(np.zeros(ngals) - 21, redshift)
alt_ms_ri_mr19 = alt_main_sequence_peak_ri(np.zeros(ngals) - 19, redshift)
alt_ms_ri_mr17 = alt_main_sequence_peak_ri(np.zeros(ngals) - 17, redshift)
alt_ms_ri_mr12 = alt_main_sequence_peak_ri(np.zeros(ngals) - 12, redshift)

fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(10, 4), sharex=True)

__=ax1.plot(redshift, ms_ri_mr25, 
           color=mred, label=r'${\rm M_{r} = -25}$')
__=ax1.plot(redshift, ms_ri_mr23, 
           color=morange, label=r'${\rm M_{r} = -23}$')
__=ax1.plot(redshift, ms_ri_mr21, 
           color='gold', label=r'${\rm M_{r} = -21}$')
__=ax1.plot(redshift, ms_ri_mr19, 
           color=mgreen, label=r'${\rm M_{r} = -19}$')
__=ax1.plot(redshift, ms_ri_mr17, 
           color=mblue, label=r'${\rm M_{r} = -17}$')
# __=ax1.plot(redshift, ms_ri_mr12, 
#            color=mpurple, label=r'${\rm M_{r} = -12}$')

# __=ax1.plot(redshift, alt_ms_ri_mr25, '--', 
#            color=mred, label=r'${\rm M_{r} = -25}$')
__=ax1.plot(redshift, alt_ms_ri_mr23, '--', 
           color=morange, label=r'${\rm M_{r} = -23}$')
__=ax1.plot(redshift, alt_ms_ri_mr21, '--', 
           color='gold', label=r'${\rm M_{r} = -21}$')
__=ax1.plot(redshift, alt_ms_ri_mr19, '--', 
           color=mgreen, label=r'${\rm M_{r} = -19}$')
__=ax1.plot(redshift, alt_ms_ri_mr17, '--', 
           color=mblue, label=r'${\rm M_{r} = -17}$')
# __=ax1.plot(redshift, alt_ms_ri_mr12, '--', 
#            color=mpurple, label=r'${\rm M_{r} = -12}$')



__=ax2.plot(redshift, rs_ri_mr25, 
           color=mred, label=r'${\rm M_{r} = -25}$')
__=ax2.plot(redshift, rs_ri_mr23, 
           color=morange, label=r'${\rm M_{r} = -23}$')
__=ax2.plot(redshift, rs_ri_mr21, 
           color='gold', label=r'${\rm M_{r} = -21}$')
__=ax2.plot(redshift, rs_ri_mr19, 
           color=mgreen, label=r'${\rm M_{r} = -19}$')
__=ax2.plot(redshift, rs_ri_mr17, 
           color=mblue, label=r'${\rm M_{r} = -17}$')


ylim = ax1.set_ylim(-0.1, 0.6)
ylim2 = ax2.set_ylim(-0.1, 0.6)
xlim = ax1.set_xlim(0, 2.)
xlabel1 = ax1.set_xlabel(r'${\rm redshift}$')
xlabel = ax2.set_xlabel(r'${\rm redshift}$')
ylabel = ax1.set_ylabel(r'${\rm r-i}$')
title = ax1.set_title(r'${\rm main\ sequence\ evolution}$')
title = ax2.set_title(r'${\rm red\ sequence\ evolution}$')


# figname = 'new_color_evolution_model.png'
# fig.savefig(figname, bbox_extra_artists=[xlabel, ylabel], bbox_inches='tight')

# %%
def sigmoid(x, x0=0, k=1, ymin=0, ymax=1):
    """
    """
    height_diff = ymax-ymin
    return ymin + height_diff/(1 + np.exp(-k*(x-x0)))


fig, ax = plt.subplots(1, 1)

# __=ax.plot(redshift, rs_ri_mr25, color=mred, label=r'${\rm M_{r} = -25}$')
# __=ax.plot(redshift, sigmoid(redshift, x0=0.8, k=7, ymin=0.42, ymax=0.22), '--', color=mred)

# __=ax.plot(redshift, rs_ri_mr23, color=morange, label=r'${\rm M_{r} = -23}$')
# __=ax.plot(redshift, sigmoid(redshift, x0=0.8, k=7, ymin=0.41, ymax=0.2), '--', color=morange)

# __=ax.plot(redshift, rs_ri_mr21, color='gold', label=r'${\rm M_{r} = -21}$')
# __=ax.plot(redshift, sigmoid(redshift, x0=0.8, k=7, ymin=0.4, ymax=0.19), '--', color='gold')

# __=ax.plot(redshift, rs_ri_mr19, color=mgreen, label=r'${\rm M_{r} = -19}$')
# __=ax.plot(redshift, sigmoid(redshift, x0=0.8, k=7, ymin=0.385, ymax=0.17), '--', color=mgreen)

# __=ax.plot(redshift, rs_ri_mr17, color=mblue, label=r'${\rm M_{r} = -17}$')
# __=ax.plot(redshift, sigmoid(redshift, x0=0.8, k=7, ymin=0.37, ymax=0.155), '--', color=mblue)

__=ax.plot(redshift, rs_ri_mr12, color=mpurple, label=r'${\rm M_{r} = -12}$')
__=ax.plot(redshift, sigmoid(redshift, x0=0.8, k=7, ymin=0.34, ymax=0.13), '--', color=mpurple)


ylim = ax.set_ylim(0.1, 0.45)
xlim = ax.set_xlim(0, 1.75)
